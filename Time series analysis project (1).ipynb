# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
sns.set_palette("rainbow")
sns.set_style("whitegrid")

# %%
df=pd.read_csv("Tomato.csv")
df
# Out:
#             Date Unit  Minimum  Maximum  Average  Market
# 0     2013-06-16   Kg       26       32     29.0  Tomato
# 1     2013-06-17   Kg       20       25     22.5  Tomato
# 2     2013-06-18   Kg       22       26     24.0  Tomato
# 3     2013-06-19   Kg       24       28     26.0  Tomato
# 4     2013-06-20   Kg       22       26     24.0  Tomato
# ...          ...  ...      ...      ...      ...     ...
# 2736  2021-05-09   Kg       10       15     12.5  Tomato
# 2737  2021-05-10   Kg       10       15     12.5  Tomato
# 2738  2021-05-11   Kg       10       15     12.5  Tomato
# 2739  2021-05-12   Kg       30       35     32.5  Tomato
# 2740  2021-05-13   Kg       35       40     37.5  Tomato
#
# [2741 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2741 entries, 0 to 2740
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2741 non-null   object
#  1   Unit     2741 non-null   object
#  2   Minimum  2741 non-null   int64
#  3   Maximum  2741 non-null   int64
#  4   Average  2741 non-null   float64
#  5   Market   2741 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 128.6+ KB

# %%
df.isna().sum()
# Out:
# Date       0
# Unit       0
# Minimum    0
# Maximum    0
# Average    0
# Market     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().round()
# Out:
#        Minimum  Maximum  Average
# count   2741.0   2741.0   2741.0
# mean      35.0     41.0     38.0
# std       17.0     17.0     17.0
# min        8.0     12.0     10.0
# 25%       22.0     30.0     25.0
# 50%       30.0     38.0     35.0
# 75%       45.0     50.0     48.0
# max      115.0    120.0    118.0

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2741 entries, 0 to 2740
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2741 non-null   datetime64[ns]
#  1   Unit     2741 non-null   object
#  2   Minimum  2741 non-null   int64
#  3   Maximum  2741 non-null   int64
#  4   Average  2741 non-null   float64
#  5   Market   2741 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 128.6+ KB

# %%
df
# Out:
#            Date Unit  Minimum  Maximum  Average  Market
# 0    2013-06-16   Kg       26       32     29.0  Tomato
# 1    2013-06-17   Kg       20       25     22.5  Tomato
# 2    2013-06-18   Kg       22       26     24.0  Tomato
# 3    2013-06-19   Kg       24       28     26.0  Tomato
# 4    2013-06-20   Kg       22       26     24.0  Tomato
# ...         ...  ...      ...      ...      ...     ...
# 2736 2021-05-09   Kg       10       15     12.5  Tomato
# 2737 2021-05-10   Kg       10       15     12.5  Tomato
# 2738 2021-05-11   Kg       10       15     12.5  Tomato
# 2739 2021-05-12   Kg       30       35     32.5  Tomato
# 2740 2021-05-13   Kg       35       40     37.5  Tomato
#
# [2741 rows x 6 columns]

# %%
df.set_index(["Date"],inplace=True)

# %%
df
# Out:
#            Unit  Minimum  Maximum  Average  Market
# Date
# 2013-06-16   Kg       26       32     29.0  Tomato
# 2013-06-17   Kg       20       25     22.5  Tomato
# 2013-06-18   Kg       22       26     24.0  Tomato
# 2013-06-19   Kg       24       28     26.0  Tomato
# 2013-06-20   Kg       22       26     24.0  Tomato
# ...         ...      ...      ...      ...     ...
# 2021-05-09   Kg       10       15     12.5  Tomato
# 2021-05-10   Kg       10       15     12.5  Tomato
# 2021-05-11   Kg       10       15     12.5  Tomato
# 2021-05-12   Kg       30       35     32.5  Tomato
# 2021-05-13   Kg       35       40     37.5  Tomato
#
# [2741 rows x 5 columns]

# %%
df.plot(figsize=(20,10))
plt.title("correlation between Minimum,Maximum and Average over the time ")
plt.show()

# %%
df["Minimum"].plot(figsize=(20,10))
plt.title("Minimum prices over the time ")
plt.show()

# %%
df["Maximum"].plot(figsize=(20,10))
plt.title("Maximum prices over the time ")
plt.show()

# %%
df["Average"].plot(figsize=(20,10))
plt.title("Average prices over the time ")
plt.show()

# %%
df[["Average"]].rolling(12).mean().plot(figsize=(20,10))
plt.title("Average prices over the time ")
plt.show()

# %%
df.to_csv("time series project")
