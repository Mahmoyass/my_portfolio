# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
sns.set_palette("rainbow")
sns.set_style("whitegrid")

# %%
df=pd.read_csv("Customer-Churn-Records.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# RowNumber             10000
# CustomerId            10000
# Surname               10000
# CreditScore           10000
# Geography             10000
# Gender                10000
# Age                   10000
# Tenure                10000
# Balance               10000
# NumOfProducts         10000
# HasCrCard             10000
# IsActiveMember        10000
# EstimatedSalary       10000
# Exited                10000
# Complain              10000
# Satisfaction Score    10000
# Card Type             10000
# Point Earned          10000
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().round()
# Out:
#        RowNumber  CustomerId  CreditScore      Age   Tenure   Balance  \
# count    10000.0     10000.0      10000.0  10000.0  10000.0   10000.0
# mean      5000.0  15690941.0        651.0     39.0      5.0   76486.0
# std       2887.0     71936.0         97.0     10.0      3.0   62397.0
# min          1.0  15565701.0        350.0     18.0      0.0       0.0
# 25%       2501.0  15628528.0        584.0     32.0      3.0       0.0
# 50%       5000.0  15690738.0        652.0     37.0      5.0   97199.0
# 75%       7500.0  15753234.0        718.0     44.0      7.0  127644.0
# max      10000.0  15815690.0        850.0     92.0     10.0  250898.0
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited  \
# count        10000.0    10000.0         10000.0          10000.0  10000.0
# mean             2.0        1.0             1.0         100090.0      0.0
# std              1.0        0.0             0.0          57510.0      0.0
# ...

# %%
cf=df.drop(columns=["RowNumber","CustomerId","Surname","Geography","Gender"])
cf
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Complain  Satisfaction Score  \
# ...

# %%
corr=cf.corr()
corr
# Out:
#                     CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore            1.000000 -0.003965  0.000842  0.006268       0.012238
# Age                   -0.003965  1.000000 -0.009997  0.028308      -0.030680
# Tenure                 0.000842 -0.009997  1.000000 -0.012254       0.013444
# Balance                0.006268  0.028308 -0.012254  1.000000      -0.304180
# NumOfProducts          0.012238 -0.030680  0.013444 -0.304180       1.000000
# HasCrCard             -0.005458 -0.011721  0.022583 -0.014858       0.003183
# IsActiveMember         0.025651  0.085472 -0.028362 -0.010084       0.009612
# EstimatedSalary       -0.001384 -0.007201  0.007784  0.012797       0.014204
# Exited                -0.026771  0.285296 -0.013656  0.118577      -0.047611
# Complain              -0.027048  0.283530 -0.013047  0.119124      -0.046357
# Satisfaction Score    -0.012599 -0.000876  0.008663 -0.002588      -0.011394
# ...

# %%
plt.matshow(corr)
plt.title("correlation between dataset ")
plt.show()

# %%
df["Geography"].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
df["HasCrCard"].value_counts()
# Out:
# 1    7055
# 0    2945
# Name: HasCrCard, dtype: int64

# %%
df["IsActiveMember"].value_counts()
# Out:
# 1    5151
# 0    4849
# Name: IsActiveMember, dtype: int64

# %%
df["Satisfaction Score"].value_counts()
# Out:
# 3    2042
# 2    2014
# 4    2008
# 5    2004
# 1    1932
# Name: Satisfaction Score, dtype: int64

# %%
df["Card Type"].value_counts()
# Out:
# DIAMOND     2507
# GOLD        2502
# SILVER      2496
# PLATINUM    2495
# Name: Card Type, dtype: int64

# %%
df["Exited"].value_counts()
# Out:
# 0    7962
# 1    2038
# Name: Exited, dtype: int64

# %%
df["Complain"].value_counts()
# Out:
# 0    7956
# 1    2044
# Name: Complain, dtype: int64

# %%
sns.countplot(x="Geography",data=df,hue="Exited",palette="pastel")
plt.title("Exited people in different countries ")
plt.show()

# %%
sns.countplot(x="IsActiveMember",data=df,hue="Exited",palette="pastel")
plt.title("correlation between Exited clients and Activity ")
plt.show()

# %%
sns.countplot(y="HasCrCard",data=df,hue="Exited",palette="pastel")
plt.title("correlation between Exited clients and credit card ")
plt.show()

# %%
sns.countplot(x="Satisfaction Score",data=df,hue="Exited",palette="pastel")
plt.title("correlation between Exited clients and satisfaction")
plt.show()

# %%
sns.countplot(x="Tenure",data=df,palette="pastel",hue="Exited")
plt.title("correlation between Exited clients and Tenure")
plt.show()

# %%
sns.countplot(x="Complain",data=df,hue="Geography",palette="pastel")
plt.title("correlation between complain clients and Geography")
plt.show()

# %%
sns.countplot(x="Complain",data=df,hue="Exited",palette="pastel")
plt.title("correlation between Exited clients and complain")
plt.show()

# %%
sns.countplot(y="Complain",data=df,hue="Gender",palette="pastel")
plt.title("correlation between complain clients and Gender")
plt.show()

# %%
sns.countplot(x="Exited",data=df,hue="Geography",palette="pastel")
plt.title("correlation between Exited clients and Geography")
plt.show()

# %%
sns.countplot(x="Card Type",data=df,hue="Geography",palette="pastel")
plt.title("correlation between Card type and Geography")
plt.show()

# %%
sns.countplot(x="Exited",data=df,hue="Gender",palette="pastel")
plt.title("correlation between Exited clients and Gender")
plt.show()

# %%
sns.kdeplot(data=df,x="CreditScore",multiple="stack",hue="Exited")
plt.title("correlation between Exited clients and Credit score")
plt.show()

# %%
sns.lineplot(data=df,x="Age",y="RowNumber",ci=None,estimator=sum,hue="Exited",markers=True)
plt.title("correlation between Exited clients and Age")
plt.ylabel("client")
plt.show()

# %%
sns.kdeplot(data=df,x="Age",multiple="stack",hue="Exited")
plt.title("correlation between Exited clients and Age")
plt.show()

# %%
sns.kdeplot(data=df,x="Tenure",multiple="stack",hue="Exited")
plt.title("correlation between Exited clients and Tenure")
plt.show()

# %%
sns.kdeplot(data=df,x="Balance",multiple="stack",hue="Exited")
plt.title("correlation between Exited clients and Balance")
plt.show()

# %%
sns.kdeplot(data=df,x="HasCrCard",multiple="stack",hue="Exited")
plt.title("correlation between Exited clients and credit card")
plt.show()

# %%
sns.lineplot(data=df,x="IsActiveMember",y="IsActiveMember",ci=None,estimator=sum,hue="Exited",markers=True)
plt.title("correlation between Exited clients and client's Activity")
plt.show()

# %%
sns.jointplot(x="Balance",y="EstimatedSalary",data=df,hue="Exited")
plt.show()

# %%
sns.kdeplot(data=df,x="EstimatedSalary",multiple="stack",hue="Exited")
plt.title("correlation between Exited clients and EstimatedSalary ")
plt.show()

# %%
sns.kdeplot(data=df,x="Balance",multiple="stack",hue="Exited")
plt.title("correlation between Exited clients and Balance ")
plt.show()

# %%
df["Exited"].plot.density()
plt.title("difference between Exited and remain clients ")
plt.show()

# %%
sns.kdeplot(data=df,x="Satisfaction Score",multiple="stack",hue="Exited")
plt.title("correlation between Exited clients and satisfaction score ")
plt.show()

# %%
sns.boxplot(x="Exited",y="EstimatedSalary",data=df)
plt.title("correlation between Exited clients and EstimatedSalary ")
plt.show()

# %%
sns.boxplot(x="Exited",y="Balance",data=df)
plt.title("correlation between Exited clients and Balance ")
plt.show()

# %%
sns.boxplot(x="Exited",y="Age",data=df)
plt.title("correlation between Exited clients and Age ")
plt.show()

# %%
sns.boxplot(x="Exited",y="Tenure",data=df)
plt.title("correlation between Exited clients and Tenure ")
plt.show()

# %%
sns.displot(df["Balance"],kde=True,bins=7)
plt.title("Distribution of balance ")
plt.show()

# %%
sns.displot(df["EstimatedSalary"],kde=True,bins=15)
plt.title("distribution of EstimatedSalary")
plt.xlabel("EstimatedSalary")
plt.ylabel("count")
plt.show()

# %%
df["Exited"].value_counts().plot.pie()
plt.title("distribution of Exited clients ")
plt.show()

# %%
plt.title(" correlation between CreditScore and point Earned ")
plt.xlabel("CreditScore")
plt.ylabel("Point Earned")
plt.scatter(data=df,x="CreditScore",y="Point Earned")
plt.legend()
plt.show()

# %%
sns.kdeplot(data=df,x="Point Earned",multiple="stack",hue="Exited")
plt.title("correlation between Exited clients and point Earned")
plt.show()

# %%
sns.kdeplot(data=df,x="Complain",multiple="stack",hue="Geography")
plt.title("correlation between complain  and Geography")
plt.show()
