# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
import plotly.express as px
sns.set_palette("rainbow")
sns.set_style("whitegrid")

# %%
df=pd.read_csv("Bikestores")
df
# Out:
#       order_id            customers        city state  order_date  \
# 0            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 1            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 2            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 3            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 4            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# ...        ...                  ...         ...   ...         ...
# 4717      1614      Dorthey Jackson     Houston    TX  11/28/2018
# 4718      1614      Dorthey Jackson     Houston    TX  11/28/2018
# 4719      1615         Sarita Parks      Forney    TX  12/28/2018
# 4720      1615         Sarita Parks      Forney    TX  12/28/2018
# 4721      1615         Sarita Parks      Forney    TX  12/28/2018
#
#       total units  revenue                                    product_name  \
# 0               2  1199.98            Electra Townie Original 7D EQ - 2016
# 1               1   599.99  Electra Townie Original 7D EQ - Women's - 2016
# 2               2  3098.00                          Surly Straggler - 2016
# 3               1  2899.99                        Trek Fuel EX 8 29 - 2016
# 4               2  3599.98           Trek Remedy 29 Carbon Frameset - 2016
# ...           ...      ...                                             ...
# 4717            1  1499.00                            Surly Krampus - 2018
# 4718            2  4599.98                        Trek Emonda ALR 6 - 2018
# 4719            1   899.99                   Electra Tiger Shark 3i - 2018
# 4720            1  2499.99                    Trek Domane SL 5 Disc - 2018
# 4721            2  4599.98                      Trek Verve+ Lowstep - 2018
#
#             category_name  store_id        store_name brand_name  \
# 0       Cruisers Bicycles         1  Santa Cruz Bikes    Electra
# 1       Cruisers Bicycles         1  Santa Cruz Bikes    Electra
# 2     Cyclocross Bicycles         1  Santa Cruz Bikes    Electra
# 3          Mountain Bikes         1  Santa Cruz Bikes    Electra
# 4          Mountain Bikes         1  Santa Cruz Bikes    Electra
# ...                   ...       ...               ...        ...
# 4717       Mountain Bikes         3     Rowlett Bikes        NaN
# 4718           Road Bikes         3     Rowlett Bikes        NaN
# 4719    Cruisers Bicycles         3     Rowlett Bikes        NaN
# 4720           Road Bikes         3     Rowlett Bikes        NaN
# 4721       Electric Bikes         3     Rowlett Bikes        NaN
#
#             sales_rep
# 0     Mireya Copeland
# 1     Mireya Copeland
# 2     Mireya Copeland
# 3     Mireya Copeland
# 4     Mireya Copeland
# ...               ...
# 4717      Kali Vargas
# 4718      Kali Vargas
# 4719      Kali Vargas
# 4720      Kali Vargas
# 4721      Kali Vargas
#
# [4722 rows x 13 columns]

# %%
df.head()
# Out:
#    order_id            customers        city state order_date  total units  \
# 0         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
# 1         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            1
# 2         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
# 3         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            1
# 4         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
#
#    revenue                                    product_name  \
# 0  1199.98            Electra Townie Original 7D EQ - 2016
# 1   599.99  Electra Townie Original 7D EQ - Women's - 2016
# 2  3098.00                          Surly Straggler - 2016
# 3  2899.99                        Trek Fuel EX 8 29 - 2016
# 4  3599.98           Trek Remedy 29 Carbon Frameset - 2016
#
#          category_name  store_id        store_name brand_name        sales_rep
# 0    Cruisers Bicycles         1  Santa Cruz Bikes    Electra  Mireya Copeland
# 1    Cruisers Bicycles         1  Santa Cruz Bikes    Electra  Mireya Copeland
# 2  Cyclocross Bicycles         1  Santa Cruz Bikes    Electra  Mireya Copeland
# 3       Mountain Bikes         1  Santa Cruz Bikes    Electra  Mireya Copeland
# 4       Mountain Bikes         1  Santa Cruz Bikes    Electra  Mireya Copeland

# %%
df.tail()
# Out:
#       order_id        customers     city state  order_date  total units  \
# 4717      1614  Dorthey Jackson  Houston    TX  11/28/2018            1
# 4718      1614  Dorthey Jackson  Houston    TX  11/28/2018            2
# 4719      1615     Sarita Parks   Forney    TX  12/28/2018            1
# 4720      1615     Sarita Parks   Forney    TX  12/28/2018            1
# 4721      1615     Sarita Parks   Forney    TX  12/28/2018            2
#
#       revenue                   product_name      category_name  store_id  \
# 4717  1499.00           Surly Krampus - 2018     Mountain Bikes         3
# 4718  4599.98       Trek Emonda ALR 6 - 2018         Road Bikes         3
# 4719   899.99  Electra Tiger Shark 3i - 2018  Cruisers Bicycles         3
# 4720  2499.99   Trek Domane SL 5 Disc - 2018         Road Bikes         3
# 4721  4599.98     Trek Verve+ Lowstep - 2018     Electric Bikes         3
#
#          store_name brand_name    sales_rep
# 4717  Rowlett Bikes        NaN  Kali Vargas
# 4718  Rowlett Bikes        NaN  Kali Vargas
# 4719  Rowlett Bikes        NaN  Kali Vargas
# 4720  Rowlett Bikes        NaN  Kali Vargas
# 4721  Rowlett Bikes        NaN  Kali Vargas

# %%
df.shape
# Out:
# (4722, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       4722 non-null   int64
#  1   customers      4722 non-null   object
#  2   city           4722 non-null   object
#  3   state          4722 non-null   object
#  4   order_date     4722 non-null   object
#  5   total units    4722 non-null   int64
#  6   revenue        4722 non-null   float64
#  7   product_name   4722 non-null   object
#  8   category_name  4722 non-null   object
#  9   store_id       4722 non-null   int64
#  10  store_name     4722 non-null   object
#  11  brand_name     2889 non-null   object
#  12  sales_rep      4722 non-null   object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 479.7+ KB

# %%
df.isna().sum()
# Out:
# order_id            0
# customers           0
# city                0
# state               0
# order_date          0
# total units         0
# revenue             0
# product_name        0
# category_name       0
# store_id            0
# store_name          0
# brand_name       1833
# sales_rep           0
# dtype: int64

# %%
sns.heatmap(df.isna())
plt.title("showing missing Data ")
plt.show()

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# order_id         0
# customers        0
# city             0
# state            0
# order_date       0
# total units      0
# revenue          0
# product_name     0
# category_name    0
# store_id         0
# store_name       0
# brand_name       0
# sales_rep        0
# dtype: int64

# %%
sns.heatmap(df.isna())
plt.title("without missing Data ")
plt.show()

# %%
df.isnull().sum()
# Out:
# order_id         0
# customers        0
# city             0
# state            0
# order_date       0
# total units      0
# revenue          0
# product_name     0
# category_name    0
# store_id         0
# store_name       0
# brand_name       0
# sales_rep        0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# order_id         2889
# customers        2889
# city             2889
# state            2889
# order_date       2889
# total units      2889
# revenue          2889
# product_name     2889
# category_name    2889
# store_id         2889
# store_name       2889
# brand_name       2889
# sales_rep        2889
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().round()
# Out:
#        order_id  total units  revenue  store_id
# count    2889.0       2889.0   2889.0    2889.0
# mean      511.0          1.0   1658.0       2.0
# std       293.0          1.0   1993.0       1.0
# min         1.0          1.0    110.0       1.0
# 25%       257.0          1.0    540.0       2.0
# 50%       520.0          1.0    900.0       2.0
# 75%       766.0          2.0   1740.0       2.0
# max      1005.0          2.0  13000.0       3.0

# %%
df.columns
# Out:
# Index(['order_id', 'customers', 'city', 'state', 'order_date', 'total units',
#        'revenue', 'product_name', 'category_name', 'store_id', 'store_name',
#        'brand_name', 'sales_rep'],
#       dtype='object')

# %%
corr=df.corr()
corr
# Out:
#              order_id  total units   revenue  store_id
# order_id     1.000000    -0.012835  0.071327  0.055674
# total units -0.012835     1.000000  0.277044 -0.004439
# revenue      0.071327     0.277044  1.000000 -0.003588
# store_id     0.055674    -0.004439 -0.003588  1.000000

# %%
plt.matshow(corr)
plt.title("correlation between dataset ")
plt.show()

# %%
df["state"].value_counts()
# Out:
# NY    1965
# CA     591
# TX     333
# Name: state, dtype: int64

# %%
df["product_name"].value_counts()
# Out:
# Electra Cruiser 1 (24-Inch) - 2016                172
# Electra Townie Original 21D - 2016                167
# Electra Townie Original 7D EQ - 2016              165
# Electra Girl's Hawaii 1 (16-inch) - 2015/2016     165
# Surly Ice Cream Truck Frameset - 2016              95
#                                                  ...
# Haro SR 1.3 - 2017                                  6
# Haro Flightline One ST - 2017                       5
# Electra Straight 8 3i (20-inch) - Boy's - 2017      4
# Trek Precaliber 16 Boys - 2017                      4
# Trek Girl's Kickster - 2017                         4
# Name: product_name, Length: 102, dtype: int64

# %%
df["category_name"].value_counts()
# Out:
# Cruisers Bicycles      904
# Mountain Bikes         776
# Children Bicycles      443
# Comfort Bicycles       343
# Cyclocross Bicycles    195
# Road Bikes             128
# Electric Bikes         100
# Name: category_name, dtype: int64

# %%
df["store_name"].value_counts()
# Out:
# Baldwin Bikes       1965
# Santa Cruz Bikes     591
# Rowlett Bikes        333
# Name: store_name, dtype: int64

# %%
df["brand_name"].value_counts()
# Out:
# Electra         321
# Haro            321
# Heller          321
# Pure Cycles     321
# Ritchey         321
# Strider         321
# Sun Bicycles    321
# Surly           321
# Trek            321
# Name: brand_name, dtype: int64

# %%
df["sales_rep"].value_counts()
# Out:
# Venita Daniel      1014
# Marcelene Boyer     951
# Genna Serrano       318
# Mireya Copeland     273
# Layla Terrell       180
# Kali Vargas         153
# Name: sales_rep, dtype: int64

# %%
date=df[["order_date"]].sample(frac=1).head(7).reset_index(drop=True)
date
# Out:
#    order_date
# 0   9/24/2017
# 1   4/17/2016
# 2   4/25/2017
# 3   4/23/2018
# 4  12/20/2017
# 5   4/27/2018
# 6   3/23/2016

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_date  7 non-null      object
# dtypes: object(1)
# memory usage: 184.0+ bytes

# %%
df["order_date"]=pd.to_datetime(df["order_date"])
df["order_date"]
# Out:
# 0      2016-01-01
# 1      2016-01-01
# 2      2016-01-01
# 3      2016-01-01
# 4      2016-01-01
#           ...
# 4717   2018-11-28
# 4718   2018-11-28
# 4719   2018-12-28
# 4720   2018-12-28
# 4721   2018-12-28
# Name: order_date, Length: 4722, dtype: datetime64[ns]

# %%
df["order_date"].dt.year
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
#         ...
# 4717    2018
# 4718    2018
# 4719    2018
# 4720    2018
# 4721    2018
# Name: order_date, Length: 4722, dtype: int64

# %%
df["order_date"].dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 4717    11
# 4718    11
# 4719    12
# 4720    12
# 4721    12
# Name: order_date, Length: 4722, dtype: int64

# %%
df["year"]=df["order_date"].dt.year
df["month"]=df["order_date"].dt.month
df
# Out:
#       order_id            customers        city state order_date  total units  \
# 0            1  Johnathan Velazquez  Pleasanton    CA 2016-01-01            2
# 1            1  Johnathan Velazquez  Pleasanton    CA 2016-01-01            1
# 2            1  Johnathan Velazquez  Pleasanton    CA 2016-01-01            2
# 3            1  Johnathan Velazquez  Pleasanton    CA 2016-01-01            1
# 4            1  Johnathan Velazquez  Pleasanton    CA 2016-01-01            2
# ...        ...                  ...         ...   ...        ...          ...
# 4717      1614      Dorthey Jackson     Houston    TX 2018-11-28            1
# 4718      1614      Dorthey Jackson     Houston    TX 2018-11-28            2
# 4719      1615         Sarita Parks      Forney    TX 2018-12-28            1
# 4720      1615         Sarita Parks      Forney    TX 2018-12-28            1
# 4721      1615         Sarita Parks      Forney    TX 2018-12-28            2
#
#       revenue                                    product_name  \
# 0     1199.98            Electra Townie Original 7D EQ - 2016
# 1      599.99  Electra Townie Original 7D EQ - Women's - 2016
# 2     3098.00                          Surly Straggler - 2016
# 3     2899.99                        Trek Fuel EX 8 29 - 2016
# 4     3599.98           Trek Remedy 29 Carbon Frameset - 2016
# ...       ...                                             ...
# 4717  1499.00                            Surly Krampus - 2018
# 4718  4599.98                        Trek Emonda ALR 6 - 2018
# 4719   899.99                   Electra Tiger Shark 3i - 2018
# 4720  2499.99                    Trek Domane SL 5 Disc - 2018
# 4721  4599.98                      Trek Verve+ Lowstep - 2018
#
#             category_name  store_id        store_name brand_name  \
# 0       Cruisers Bicycles         1  Santa Cruz Bikes    Electra
# 1       Cruisers Bicycles         1  Santa Cruz Bikes    Electra
# 2     Cyclocross Bicycles         1  Santa Cruz Bikes    Electra
# 3          Mountain Bikes         1  Santa Cruz Bikes    Electra
# 4          Mountain Bikes         1  Santa Cruz Bikes    Electra
# ...                   ...       ...               ...        ...
# 4717       Mountain Bikes         3     Rowlett Bikes        NaN
# 4718           Road Bikes         3     Rowlett Bikes        NaN
# 4719    Cruisers Bicycles         3     Rowlett Bikes        NaN
# 4720           Road Bikes         3     Rowlett Bikes        NaN
# 4721       Electric Bikes         3     Rowlett Bikes        NaN
#
#             sales_rep  year  month
# 0     Mireya Copeland  2016      1
# 1     Mireya Copeland  2016      1
# 2     Mireya Copeland  2016      1
# 3     Mireya Copeland  2016      1
# 4     Mireya Copeland  2016      1
# ...               ...   ...    ...
# 4717      Kali Vargas  2018     11
# 4718      Kali Vargas  2018     11
# 4719      Kali Vargas  2018     12
# 4720      Kali Vargas  2018     12
# 4721      Kali Vargas  2018     12
#
# [4722 rows x 15 columns]

# %%
cd=df.groupby(["year"],as_index=False)["revenue"].sum().sort_values(by="revenue",ascending=False)
sns.barplot(data=cd,x="year",y="revenue")
plt.title(" Total Revenue ")
plt.show()

# %%
cd=df.groupby(["sales_rep"],as_index=False)["revenue"].sum().sort_values(by="revenue",ascending=False)
sns.barplot(data=cd,x="revenue",y="sales_rep")
plt.title("Revenue by sales_rep")
plt.show()

# %%
cd=df.groupby(["category_name"],as_index=False)["revenue"].sum().sort_values(by="revenue",ascending=False)

ax=sns.barplot(data=cd,x="revenue",y="category_name")
plt.title("Revenue by category_name")
plt.show()

# %%
cd=df.groupby(["brand_name"],as_index=False)["revenue"].sum().sort_values(by="revenue",ascending=False)

ax=sns.barplot(data=cd,x="revenue",y="brand_name")
plt.title("Revenue by brand")
plt.show()

# %%
cd=df.groupby(["customers"],as_index=False)["revenue"].sum().sort_values(by="revenue",ascending=False).head(10)

ax=sns.barplot(data=cd,x="revenue",y="customers")
plt.title("TOP TEN CUSTOMERS")
plt.show()

# %%
df["revenue"].groupby(df["store_name"]).sum().plot.pie(radius=1.5,autopct="%0.1f%%")
plt.axis("equal")
plt.title("Revenue by store")
plt.show()

# %%
df["revenue"].groupby(df["state"]).sum().plot.pie(radius=1.5,autopct="%0.1f%%")
plt.axis("equal")
cr=plt.Circle(xy=(0,0),radius=1,facecolor="w")
plt.gca().add_artist(cr)
plt.title("Revenue by state")
plt.show()

# %%
sns.lineplot(data=df,x="month",y="revenue",ci=None,estimator=sum,markers=True,hue="year",palette="pastel")
plt.title("Revenue per month")
plt.show()

# %%
df["product_name"].value_counts().head(10).plot.pie()
plt.title("TOP TEN PRODUCTS")
plt.show()

# %%
sns.kdeplot(data=df,x="revenue",multiple="stack",hue="year")
plt.title("Revenue per year ")
plt.show()

# %%
sns.kdeplot(data=df,x="revenue",multiple="stack",hue="month")
plt.title("Revenue per Month ")
plt.show()

# %%
sns.kdeplot(data=df,x="revenue",multiple="stack",hue="state")
plt.title("Revenue by State ")
plt.show()

# %%
sns.kdeplot(data=df,x="revenue",multiple="stack",hue="store_name")
plt.title("Revenue by Store")
plt.show()

# %%
sns.boxplot(x="state",y="revenue",data=df)
plt.title(" minimum and maximum Revenue in each state")
plt.show()

# %%
sns.displot(df["revenue"],kde=True,bins=7)
plt.title("Distribution of revenue ")
plt.show()

# %%
sns.countplot(x="state",data=df,hue="brand_name",palette="pastel")
plt.title("count of brands in each country")
plt.show()

# %%
sns.countplot(x="store_name",data=df,hue="category_name",palette="pastel")
plt.title("count of category in each brand")
plt.show()

# %%
sns.countplot(y="sales_rep",data=df,palette="pastel")
plt.title("count of sales_rep")
plt.show()
