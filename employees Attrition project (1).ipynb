# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
sns.set_palette("rainbow")
sns.set_style("whitegrid")

# %%
df=pd.read_csv("HR-Employee-Attrition2.csv")
df
# Out:
#      Attrition  DistanceFromHome  EnvironmentSatisfaction  JobSatisfaction  \
# 0          Yes                 3                        3                3
# 1           No                10                        4                3
# 2          Yes                 5                        2                2
# 3           No                 5                        2                4
# 4          Yes                 8                        3                3
# ...        ...               ...                      ...              ...
# 1465        No                 7                        1                1
# 1466        No                28                        3                1
# 1467        No                16                        1                1
# 1468        No                 7                        2                4
# 1469        No                 1                        3                4
#
#       MonthlyIncome  PercentSalaryHike  RelationshipSatisfaction  \
# ...

# %%
df.head()
# Out:
#   Attrition  DistanceFromHome  EnvironmentSatisfaction  JobSatisfaction  \
# 0       Yes                 3                        3                3
# 1        No                10                        4                3
# 2       Yes                 5                        2                2
# 3        No                 5                        2                4
# 4       Yes                 8                        3                3
#
#    MonthlyIncome  PercentSalaryHike  RelationshipSatisfaction  \
# 0           1420                 13                         3
# 1           1200                 12                         1
# 2           1878                 14                         4
# 3           1051                 15                         4
# 4           1904                 12                         4
#
#    WorkLifeBalance  YearsInCurrentRole  YearsSinceLastPromotion
# 0                3                   0                        0
# ...

# %%
df.tail()
# Out:
#      Attrition  DistanceFromHome  EnvironmentSatisfaction  JobSatisfaction  \
# 1465        No                 7                        1                1
# 1466        No                28                        3                1
# 1467        No                16                        1                1
# 1468        No                 7                        2                4
# 1469        No                 1                        3                4
#
#       MonthlyIncome  PercentSalaryHike  RelationshipSatisfaction  \
# 1465          19566                 11                         4
# 1466          10266                 19                         4
# 1467           5405                 14                         4
# 1468           5220                 18                         2
# 1469          10883                 20                         3
#
#       WorkLifeBalance  YearsInCurrentRole  YearsSinceLastPromotion
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1470 non-null   object
#  1   DistanceFromHome          1470 non-null   int64
#  2   EnvironmentSatisfaction   1470 non-null   int64
#  3   JobSatisfaction           1470 non-null   int64
#  4   MonthlyIncome             1470 non-null   int64
#  5   PercentSalaryHike         1470 non-null   int64
#  6   RelationshipSatisfaction  1470 non-null   int64
#  7   WorkLifeBalance           1470 non-null   int64
#  8   YearsInCurrentRole        1470 non-null   int64
#  9   YearsSinceLastPromotion   1470 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 115.0+ KB

# %%
df.isna().sum()
# Out:
# Attrition                   0
# DistanceFromHome            0
# EnvironmentSatisfaction     0
# JobSatisfaction             0
# MonthlyIncome               0
# PercentSalaryHike           0
# RelationshipSatisfaction    0
# WorkLifeBalance             0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().round()
# Out:
#        DistanceFromHome  EnvironmentSatisfaction  JobSatisfaction  \
# count            1470.0                   1470.0           1470.0
# mean                9.0                      3.0              3.0
# std                 8.0                      1.0              1.0
# min                 1.0                      1.0              1.0
# 25%                 2.0                      2.0              2.0
# 50%                 7.0                      3.0              3.0
# 75%                14.0                      4.0              4.0
# max                29.0                      4.0              4.0
#
#        MonthlyIncome  PercentSalaryHike  RelationshipSatisfaction  \
# count         1470.0             1470.0                    1470.0
# mean          6503.0               15.0                       3.0
# std           4708.0                4.0                       1.0
# min           1009.0               11.0                       1.0
# ...

# %%
corr=df.corr()
corr
# Out:
#                           DistanceFromHome  EnvironmentSatisfaction  \
# DistanceFromHome                  1.000000                -0.016075
# EnvironmentSatisfaction          -0.016075                 1.000000
# JobSatisfaction                  -0.003669                -0.006784
# MonthlyIncome                    -0.017014                -0.006259
# PercentSalaryHike                 0.040235                -0.031701
# RelationshipSatisfaction          0.006557                 0.007665
# WorkLifeBalance                  -0.026556                 0.027627
# YearsInCurrentRole                0.018845                 0.018007
# YearsSinceLastPromotion           0.010029                 0.016194
#
#                           JobSatisfaction  MonthlyIncome  PercentSalaryHike  \
# DistanceFromHome                -0.003669      -0.017014           0.040235
# EnvironmentSatisfaction         -0.006784      -0.006259          -0.031701
# ...

# %%
plt.matshow(corr)
plt.show()

# %%
df["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
sns.countplot(x="Attrition",data=df,hue="Attrition",palette="pastel")
plt.title("count of employees Attrition ")
plt.show()

# %%
sns.boxplot(x="Attrition",y="MonthlyIncome",data=df)
plt.title("correlation between employees Attrition  and MonthlyIncome ")
plt.show()

# %%
sns.countplot(x="EnvironmentSatisfaction",hue="Attrition",data=df,palette="pastel")
plt.title("correlation between employees Attrition  and EnvironmentSatisfaction ")
plt.show()

# %%
sns.countplot(x="JobSatisfaction",hue="Attrition",data=df,palette="pastel")
plt.title("correlation between employees Attrition  and  JobSatisfaction")
plt.show()

# %%
sns.countplot(x="PercentSalaryHike",hue="Attrition",data=df,palette="pastel")
plt.title("correlation between employees Attrition  and PercentSalaryHike ")
plt.show()

# %%
sns.countplot(x="WorkLifeBalance",hue="Attrition",data=df,palette="pastel")
plt.title("correlation between employees Attrition  and WorkLifeBalance ")
plt.show()

# %%
sns.countplot(x="YearsSinceLastPromotion",hue="Attrition",data=df,palette="pastel")
plt.title("correlation between employees Attrition  and YearsSinceLastPromotion ")
plt.show()

# %%
sns.countplot(x="RelationshipSatisfaction",hue="Attrition",data=df,palette="pastel")
plt.title("correlation between employees Attrition  and RelationshipSatisfaction ")
plt.show()

# %%
sns.kdeplot(data=df,x="MonthlyIncome",multiple="stack",hue="Attrition")
plt.title("correlation between employees Attrition  and MonthlyIncome")
plt.show()

# %%
sns.kdeplot(data=df,x="EnvironmentSatisfaction",multiple="stack",hue="Attrition")
plt.title("correlation between employees Attrition  and EnvironmentSatisfaction")
plt.show()

# %%
sns.kdeplot(data=df,x="JobSatisfaction",multiple="stack",hue="Attrition")
plt.title("correlation between employees Attrition  and JobSatisfaction")
plt.show()

# %%
sns.lineplot(data=df,x="PercentSalaryHike",y="Attrition",ci=None,estimator=sum,hue="Attrition",markers=True)
plt.title("correlation between employees Attrition  and PercentSalaryHike")
plt.show()

# %%
sns.kdeplot(data=df,x="WorkLifeBalance",multiple="stack",hue="Attrition")
plt.title("correlation between employees Attrition  and WorkLifeBalance")
plt.show()

# %%
sns.kdeplot(data=df,x="YearsSinceLastPromotion",multiple="stack",hue="Attrition")
plt.title("correlation between employees Attrition  and YearsSinceLastPromotion")
plt.show()

# %%
df["Attrition"].value_counts().plot.pie()
plt.title("count of employees Attrition ")
plt.show()

# %%
sns.displot(df["MonthlyIncome"],kde=True,bins=7)
plt.title("Distribution of MonthlyIncome ")
plt.show()
