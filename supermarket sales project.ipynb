# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_palette("rainbow")
sns.set_style("whitegrid")

# %%
df=pd.read_csv("supermarket_sales - Sheet1.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().round()
# Out:
#        Unit price  Quantity  Tax 5%   Total    cogs  gross margin percentage  \
# count      1000.0    1000.0  1000.0  1000.0  1000.0                   1000.0
# mean         56.0       6.0    15.0   323.0   308.0                      5.0
# std          26.0       3.0    12.0   246.0   234.0                      0.0
# min          10.0       1.0     1.0    11.0    10.0                      5.0
# 25%          33.0       3.0     6.0   124.0   118.0                      5.0
# 50%          55.0       5.0    12.0   254.0   242.0                      5.0
# 75%          78.0       8.0    22.0   471.0   449.0                      5.0
# max         100.0      10.0    50.0  1043.0   993.0                      5.0
#
#        gross income  Rating
# count        1000.0  1000.0
# mean           15.0     7.0
# std            12.0     2.0
# min             1.0     4.0
# 25%             6.0     6.0
# 50%            12.0     7.0
# 75%            22.0     8.0
# max            50.0    10.0

# %%
corr=df.corr()
corr
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# ...

# %%
plt.matshow(corr)
plt.show()

# %%
df["Branch"].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
df["Customer type"].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
df["Product line"].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
df["Payment"].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
sns.countplot(x="Branch",data=df,palette="pastel",hue="Product line")
plt.title("count of sales of each branch ")
plt.show()

# %%
sns.countplot(x="Customer type",data=df,palette="pastel",hue="Branch")
plt.title("Customer type by Branch")
plt.show()

# %%
sns.countplot(x="Gender",data=df,palette="pastel",hue="Branch")
plt.title("count of gender by Branch ")
plt.show()

# %%
sns.countplot(x="Payment",data=df,palette="pastel",hue="Branch")
plt.title("methods of payment of each branch ")
plt.show()

# %%
sns.boxplot(x="Branch",y="gross income",data=df)
plt.title("gross income of each branch ")
plt.show()

# %%
df["City"].value_counts().plot.pie()
plt.title("  Cities of the branches ")
plt.show()

# %%
sns.kdeplot(data=df,x="Rating",multiple="stack",hue="Branch")
plt.title("Rating of the Branches ")
plt.show()

# %%
sns.boxplot(x="Product line",y="Unit price",data=df)
plt.title("Unit price of each Product ")
plt.show()

# %%
sns.displot(df["gross income"],kde=True,bins=7)
plt.title("Distribution of gross income  ")
plt.show()

# %%
sns.displot(df["Unit price"],kde=True,bins=7)
plt.title("Distribution of Unit price  ")
plt.show()
